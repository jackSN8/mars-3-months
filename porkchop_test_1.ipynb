# %%
import astropy.units as u

from poliastro.plotting.porkchop import porkchop
from poliastro.bodies import Earth, Mars
from poliastro.util import time_range

launch_span = time_range("2030-09-30", end="2033-08-07")
arrival_span = time_range("2031-01-16", end="2033-12-21")

# %%
dv_dpt, dv_arr, c3dpt, c3arr, tof = porkchop(Earth, Mars, 
                                             launch_span, arrival_span,max_c3=45 * u.km**2 / u.s**2)
